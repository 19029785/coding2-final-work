# %%
# !pip install samila
# Out:
# Requirement already satisfied: samila in /Users/Estelle/miniforge3/envs/coding2/lib/python3.9/site-packages/samila-1.0-py3.9.egg (1.0)
# Requirement already satisfied: matplotlib>=3.0.0 in /Users/Estelle/miniforge3/envs/coding2/lib/python3.9/site-packages (from samila) (3.7.1)
# Requirement already satisfied: requests>=2.20.0 in /Users/Estelle/miniforge3/envs/coding2/lib/python3.9/site-packages (from samila) (2.28.2)
# Requirement already satisfied: art>=1.8 in /Users/Estelle/miniforge3/envs/coding2/lib/python3.9/site-packages (from samila) (5.9)
# Requirement already satisfied: packaging>=20.0 in /Users/Estelle/miniforge3/envs/coding2/lib/python3.9/site-packages (from matplotlib>=3.0.0->samila) (23.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/Estelle/miniforge3/envs/coding2/lib/python3.9/site-packages (from matplotlib>=3.0.0->samila) (5.10.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/Estelle/miniforge3/envs/coding2/lib/python3.9/site-packages (from matplotlib>=3.0.0->samila) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /Users/Estelle/miniforge3/envs/coding2/lib/python3.9/site-packages (from matplotlib>=3.0.0->samila) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/Estelle/miniforge3/envs/coding2/lib/python3.9/site-packages (from matplotlib>=3.0.0->samila) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/Estelle/miniforge3/envs/coding2/lib/python3.9/site-packages (from matplotlib>=3.0.0->samila) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/Estelle/miniforge3/envs/coding2/lib/python3.9/site-packages (from matplotlib>=3.0.0->samila) (2.8.2)
# Requirement already satisfied: numpy>=1.20 in /Users/Estelle/miniforge3/envs/coding2/lib/python3.9/site-packages (from matplotlib>=3.0.0->samila) (1.23.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/Estelle/miniforge3/envs/coding2/lib/python3.9/site-packages (from matplotlib>=3.0.0->samila) (4.39.0)
# Requirement already satisfied: cycler>=0.10 in /Users/Estelle/miniforge3/envs/coding2/lib/python3.9/site-packages (from matplotlib>=3.0.0->samila) (0.11.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/Estelle/miniforge3/envs/coding2/lib/python3.9/site-packages (from requests>=2.20.0->samila) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Estelle/miniforge3/envs/coding2/lib/python3.9/site-packages (from requests>=2.20.0->samila) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/Estelle/miniforge3/envs/coding2/lib/python3.9/site-packages (from requests>=2.20.0->samila) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Estelle/miniforge3/envs/coding2/lib/python3.9/site-packages (from requests>=2.20.0->samila) (2022.12.7)
# Requirement already satisfied: zipp>=3.1.0 in /Users/Estelle/miniforge3/envs/coding2/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0.0->samila) (3.12.1)
# Requirement already satisfied: six>=1.5 in /Users/Estelle/miniforge3/envs/coding2/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->samila) (1.16.0)

# %%
import matplotlib.pyplot as plt
import random
import math
from samila import GenerativeImage, Projection

# %%
def f1(x, y):
    result = random.uniform(-1,1) * x**3  - math.cos(y**2) + abs(y-x)
    return result

def f2(x, y):
    result = random.uniform(-1,1) * y**3 - math.cos(x**2) + 2*x
    return result

g = GenerativeImage(f1, f2)
g.generate()
g.seed
# Out:
# 956947

# %%
g.plot(projection= Projection.POLAR, color = 'black',bgcolor = 'white')
